# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.neural_network import MLPRegressor

# %%
df = pd.read_csv('apple_quality.csv')
data = df.drop(index = 4000)
le = LabelEncoder()
data['Quality'] =le.fit_transform(data['Quality'])
scaler = MinMaxScaler()
df = scaler.fit_transform(data)
df = pd.DataFrame(df,columns=data.columns)
del df['A_id']
df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     0.234669  0.358370   0.922484     0.368781   0.585819  0.472770
# 1     0.439331  0.333107   0.795706     0.558928   0.511408  0.513807
# 2     0.505948  0.448092   0.388567     0.417732   0.660388  0.444693
# 3     0.479014  0.376971   0.619422     0.435629   0.720370  0.187052
# 4     0.628107  0.452317   0.490589     0.402347   0.674814  0.348084
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.531867  0.470029   0.239644     0.477379   0.574794  0.618866
# 3996  0.505867  0.703146   0.504203     0.395971   0.449218  0.364566
# 3997  0.333173  0.387278   0.335661     0.490846   0.612443  0.811182
# 3998  0.231869  0.415014   0.697913     0.428137   0.609571  0.463966
# 3999  0.548031  0.419946   0.528713     0.358392   0.542429  0.388327
#
#        Acidity  Quality
# 0     0.452225      1.0
# 1     0.436185      1.0
# 2     0.668192      0.0
# 3     0.541180      1.0
# 4     0.521150      1.0
# ...        ...      ...
# 3995  0.495885      0.0
# 3996  0.614957      1.0
# 3997  0.393744      0.0
# 3998  0.331650      1.0
# 3999  0.597306      1.0
#
# [4000 rows x 8 columns]

# %%
X = df.drop('Quality',axis=1)
y = df["Quality"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=18)

# %%
model_3 = MLPRegressor(activation='relu',
                       random_state=18,
                       hidden_layer_sizes=(64,32,16),
                       alpha=0.001,
                       batch_size=32,
                       solver='adam',
                       verbose=True,
                       max_iter=250,
                       n_iter_no_change=100,
                       learning_rate_init=0.001,
                       momentum=0.9)
model_3.fit(X_train,y_train)
y_pred_test = model_3.predict(X_test)
y_pred_train = model_3.predict(X_train)
r2_test = r2_score(y_test,y_pred_test)
r2_train = r2_score(y_train,y_pred_train)
print(f'r2_test: {r2_test},  r2_train  : {r2_train}')
plt.figure(figsize=(8,5))
plt.plot(model_3.loss_curve_, color='b', linewidth=2)
plt.title('Iteration-Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.grid(True)
plt.show()
model_3
# Out:
# Iteration 1, loss = 0.11168907
# Iteration 2, loss = 0.08880415
# Iteration 3, loss = 0.08058207
# Iteration 4, loss = 0.07509775
# Iteration 5, loss = 0.07028635
# Iteration 6, loss = 0.06544761
# Iteration 7, loss = 0.06271880
# Iteration 8, loss = 0.06204847
# Iteration 9, loss = 0.05962779
# Iteration 10, loss = 0.05825232
# Iteration 11, loss = 0.05616405
# Iteration 12, loss = 0.05612437
# Iteration 13, loss = 0.05483736
# Iteration 14, loss = 0.05371165
# Iteration 15, loss = 0.05234615
# Iteration 16, loss = 0.05121650
# Iteration 17, loss = 0.05213142
# Iteration 18, loss = 0.05189197
# Iteration 19, loss = 0.05159266
# Iteration 20, loss = 0.05016677
# Iteration 180, loss = 0.02283515
# Iteration 181, loss = 0.02114929
# Iteration 182, loss = 0.02140415
# Iteration 183, loss = 0.02059338
# Iteration 184, loss = 0.02237693
# Iteration 185, loss = 0.02220128
# Iteration 186, loss = 0.02306865
# Iteration 187, loss = 0.02120632
# Iteration 188, loss = 0.02082439
# Iteration 189, loss = 0.02636013
# Iteration 190, loss = 0.02139626
# Iteration 191, loss = 0.02152134
# Iteration 192, loss = 0.02070129
# Iteration 193, loss = 0.02105813
# Iteration 194, loss = 0.02041634
# Iteration 195, loss = 0.02182289
# Iteration 196, loss = 0.02142698
# Iteration 197, loss = 0.02037658
# Iteration 198, loss = 0.02222981
# Iteration 199, loss = 0.02176312
# Iteration 200, loss = 0.02067564
# Iteration 201, loss = 0.02148681
# Iteration 202, loss = 0.02185938
# Iteration 203, loss = 0.02120686
# Iteration 204, loss = 0.02124723
# Iteration 205, loss = 0.02095773
# Iteration 206, loss = 0.02048179
# Iteration 207, loss = 0.02115038
# Iteration 208, loss = 0.02130181
# Iteration 209, loss = 0.02378635
# Iteration 210, loss = 0.02128109
# Iteration 211, loss = 0.02124770
# Iteration 212, loss = 0.02053344
# Iteration 213, loss = 0.02267227
# Iteration 214, loss = 0.02019528
# Iteration 215, loss = 0.02344176
# Iteration 216, loss = 0.02159133
# Iteration 217, loss = 0.01948606
# Iteration 218, loss = 0.02092312
# Iteration 219, loss = 0.02007769
# Iteration 220, loss = 0.02345105
# Iteration 221, loss = 0.02097946
# Iteration 222, loss = 0.02168238
# Iteration 223, loss = 0.01988769
# Iteration 224, loss = 0.02053557
# Iteration 225, loss = 0.02087827
# Iteration 226, loss = 0.02038351
# Iteration 227, loss = 0.02087101
# Iteration 228, loss = 0.02108683
# Iteration 229, loss = 0.01965611
# Iteration 230, loss = 0.01939959
# Iteration 231, loss = 0.02123531
# Iteration 232, loss = 0.02210874
# Iteration 233, loss = 0.02023042
# Iteration 234, loss = 0.02145484
# Iteration 235, loss = 0.02008206
# Iteration 236, loss = 0.01904329
# Iteration 237, loss = 0.02028506
# Iteration 238, loss = 0.01913920
# Iteration 239, loss = 0.01937594
# Iteration 240, loss = 0.02206961
# Iteration 241, loss = 0.02037728
# Iteration 242, loss = 0.02051872
# Iteration 243, loss = 0.02118125
# Iteration 244, loss = 0.02161286
# Iteration 245, loss = 0.01925272
# Iteration 246, loss = 0.02038068
# Iteration 247, loss = 0.02062968
# Iteration 248, loss = 0.01887263
# Iteration 249, loss = 0.01906630
# Iteration 250, loss = 0.02030137
# c:\Users\beach\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (250) reached and the optimization hasn't converged yet.
#   warnings.warn(
# r2_test: 0.8343258053016068,  r2_train  : 0.8685044255459575
# MLPRegressor(alpha=0.001, batch_size=32, hidden_layer_sizes=(64, 32, 16),
#              max_iter=250, n_iter_no_change=100, random_state=18, verbose=True)
